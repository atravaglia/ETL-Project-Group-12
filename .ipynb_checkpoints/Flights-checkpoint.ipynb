# %%
# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
import scipy.stats as st
from scipy.stats import linregress

# %%
# Output File (CSV)
flight_data_2015_path = "Resources/2015_Flights.csv"

# %%
flight_data_2015 = pd.read_csv(flight_data_2015_path)
flight_data_2015.head()
# Out:
#    MONTH  DAY      DATE  FLIGHT_NUMBER TAIL_NUMBER ORIGIN_AIRPORT  \
# 0      1    1  1/1/2015            136      N431AS            ANC
# 1      1    1  1/1/2015           2459      N3BDAA            PHX
# 2      1    1  1/1/2015           5254      N746SK            MAF
# 3      1    1  1/1/2015           2859      N660MQ            SGF
# 4      1    1  1/1/2015           5460      N583SW            RDD
#
#   DESTINATION_AIRPORT  CANCELLED CANCELLATION_CODE            ID
# 0                 SEA          1                 A   11136N431AS
# 1                 DFW          1                 B  112459N3BDAA
# 2                 IAH          1                 B  115254N746SK
# 3                 DFW          1                 B  112859N660MQ
# 4                 SFO          1                 A  115460N583SW

# %%
# Output File (CSV)
flight_data_2020_path = "Resources/2020_flights.csv"

# %%
flight_data_2020 = pd.read_csv(flight_data_2020_path)
flight_data_2020.head()
# Out:
#    MONTH  DAY     DATE  FLIGHT_NUMBER TAIL_NUMBER ORIGIN_AIRPORT  \
# 0      1    1   1/1/20           6173      N7831B            PDX
# 1      1    1   1/1/20           4433      N488WN            SNA
# 2      1   20  1/20/20            423      N209WN            DAL
# 3      1   20  1/20/20           1519      N467WN            DAL
# 4      1   30  1/30/20           1845      N741SA            MSY
#
#   DESTINATION_AIRPORT  CANCELLED CANCELLATION_CODE             ID
# 0                 LAS          1                 A   116173N7831B
# 1                 OAK          1                 A   114433N488WN
# 2                 PHX          1                 A   120423N209WN
# 3                 SAT          1                 A  1201519N467WN
# 4                 HOU          1                 A  1301845N741SA

# %%
flight_data_2015["ID"].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 40522    False
# 40523    False
# 40524    False
# 40525    False
# 40526    False
# Name: ID, Length: 40527, dtype: bool

# %%
flight_data_2015 = flight_data_2015.loc[(flight_data_2015["MONTH"]==1)|(flight_data_2015["MONTH"]==2)]

# %%
flight_data_2015
# Out:
#        MONTH  DAY       DATE  FLIGHT_NUMBER TAIL_NUMBER ORIGIN_AIRPORT  \
# 0          1    1   1/1/2015            136      N431AS            ANC
# 1          1    1   1/1/2015           2459      N3BDAA            PHX
# 2          1    1   1/1/2015           5254      N746SK            MAF
# 3          1    1   1/1/2015           2859      N660MQ            SGF
# 4          1    1   1/1/2015           5460      N583SW            RDD
# ...      ...  ...        ...            ...         ...            ...
# 32494      2   28  2/28/2015           1069      N3KBAA            DFW
# 32495      2   28  2/28/2015           1329      N505AA            DFW
# 32496      2   28  2/28/2015             81      N425AA            DFW
# 32497      2   28  2/28/2015           2274      N4YAAA            DFW
# 32498      2   28  2/28/2015           1230      N3JYAA            SEA
#
#       DESTINATION_AIRPORT  CANCELLED CANCELLATION_CODE             ID
# 0                     SEA          1                 A    11136N431AS
# 1                     DFW          1                 B   112459N3BDAA
# 2                     IAH          1                 B   115254N746SK
# 3                     DFW          1                 B   112859N660MQ
# 4                     SFO          1                 A   115460N583SW
# ...                   ...        ...               ...            ...
# 32494                 DEN          1                 B  2281069N3KBAA
# 32495                 LAS          1                 B  2281329N505AA
# 32496                 TUS          1                 B    22881N425AA
# 32497                 OKC          1                 B  2282274N4YAAA
# 32498                 DFW          1                 B  2281230N3JYAA
#
# [32499 rows x 10 columns]

# %%
flight_data_2020["ID"].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12622    False
# 12623    False
# 12624    False
# 12625     True
# 12626    False
# Name: ID, Length: 12627, dtype: bool

# %%
#flight_data_2020["ID"].drop_duplicates()

# %%
flight_data_2020["ORIGIN_AIRPORT"].value_counts()
# Out:
# ORD    1405
# CLT     691
# DFW     524
# MDW     402
# DEN     346
#        ...
# IAG       1
# PPG       1
# RHI       1
# OTZ       1
# BJI       1
# Name: ORIGIN_AIRPORT, Length: 325, dtype: int64

# %%
count_2020_or = flight_data_2020["ORIGIN_AIRPORT"].value_counts()

# %%
count_2020_or_df = pd.DataFrame(count_2020_or)
count_2020_or_df.iloc[:10]
# Out:
#      ORIGIN_AIRPORT
# ORD            1405
# CLT             691
# DFW             524
# MDW             402
# DEN             346
# DCA             297
# SEA             272
# DAL             272
# PHL             261
# SFO             252

# %%
flight_data_2020["ORIGIN_AIRPORT"].value_counts()
# Out:
# ORD    1405
# CLT     691
# DFW     524
# MDW     402
# DEN     346
#        ...
# IAG       1
# PPG       1
# RHI       1
# OTZ       1
# BJI       1
# Name: ORIGIN_AIRPORT, Length: 325, dtype: int64

# %%
count_2020_dest = flight_data_2020["ORIGIN_AIRPORT"].value_counts()

# %%
count_2020_dest = pd.DataFrame(count_2020_dest)
count_2020_or_df.iloc[:10]
# Out:
#      ORIGIN_AIRPORT
# ORD            1405
# CLT             691
# DFW             524
# MDW             402
# DEN             346
# DCA             297
# SEA             272
# DAL             272
# PHL             261
# SFO             252

# %%
flight_data_2020 = flight_data_2020[flight_data_2020.ORIGIN_AIRPORT != "USA"]

# %%
flight_data_2020 = flight_data_2020[flight_data_2020.DESTINATION_AIRPORT != "USA"]

# %%
flight_data_2015["ORIGIN_AIRPORT"].value_counts()
# Out:
# ORD    2817
# DFW    2524
# LGA    1950
# BOS    1793
# EWR    1275
#        ...
# CDC       1
# BJI       1
# PBG       1
# CNY       1
# MLB       1
# Name: ORIGIN_AIRPORT, Length: 306, dtype: int64

# %%
count_2015_dest = flight_data_2015["DESTINATION_AIRPORT"].value_counts()

# %%
count_2015_dest_df = pd.DataFrame(count_2015_dest)
count_2015_dest_df.iloc[:10]
# Out:
#      DESTINATION_AIRPORT
# ORD                 2965
# DFW                 2647
# LGA                 1898
# BOS                 1781
# EWR                 1315
# ATL                 1291
# JFK                  957
# DCA                  851
# DEN                  703
# SFO                  677

# %%
count_2015_or = flight_data_2015["ORIGIN_AIRPORT"].value_counts()

# %%
count_2015_or_df = pd.DataFrame(count_2015_or)
count_2015_or_df.iloc[:10]
# Out:
#      ORIGIN_AIRPORT
# ORD            2817
# DFW            2524
# LGA            1950
# BOS            1793
# EWR            1275
# ATL            1195
# JFK             945
# DCA             890
# MDW             697
# DEN             674

# %%
flights_all = pd.concat([flight_data_2015, flight_data_2020])

# %%
flights_all
# Out:
#        MONTH  DAY      DATE  FLIGHT_NUMBER TAIL_NUMBER ORIGIN_AIRPORT  \
# 0          1    1  1/1/2015            136      N431AS            ANC
# 1          1    1  1/1/2015           2459      N3BDAA            PHX
# 2          1    1  1/1/2015           5254      N746SK            MAF
# 3          1    1  1/1/2015           2859      N660MQ            SGF
# 4          1    1  1/1/2015           5460      N583SW            RDD
# ...      ...  ...       ...            ...         ...            ...
# 12622      2    4    2/4/20           4359      N112HQ            DCA
# 12623      2    5    2/5/20           4360         NaN            OKC
# 12624      2    7    2/7/20           4362      N421YX            LGA
# 12625      2    7    2/7/20           4362      N421YX            TYS
# 12626      2    7    2/7/20           4367      N125HQ            SDF
#
#       DESTINATION_AIRPORT  CANCELLED CANCELLATION_CODE            ID
# 0                     SEA          1                 A   11136N431AS
# 1                     DFW          1                 B  112459N3BDAA
# 2                     IAH          1                 B  115254N746SK
# 3                     DFW          1                 B  112859N660MQ
# 4                     SFO          1                 A  115460N583SW
# ...                   ...        ...               ...           ...
# 12622                 OKC          1                 B  244359N112HQ
# 12623                 DCA          1                 C        254360
# 12624                 TYS          1                 B  274362N421YX
# 12625                 LGA          1                 B  274362N421YX
# 12626                 CLT          1                 B  274367N125HQ
#
# [45124 rows x 10 columns]

# %%
#flights_all = pd.merge(flight_data_2015, flight_data_2020, how="outer", on="DATE")

# %%
#flights_all.head()
