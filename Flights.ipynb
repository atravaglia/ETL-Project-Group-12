# %%
# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
import scipy.stats as st
from scipy.stats import linregress

# %%
# Output File (CSV)
flight_data_2015_path = "Resources/2015_Flights.csv"

# %%
flight_data_2015 = pd.read_csv(flight_data_2015_path)
flight_data_2015.head()
# Out:
#    MONTH  DAY    Date  FLIGHT_NUMBER TAIL_NUMBER ORIGIN_AIRPORT  \
# 0      1    1  1/1/15            136      N431AS            ANC
# 1      1    1  1/1/15           2459      N3BDAA            PHX
# 2      1    1  1/1/15           5254      N746SK            MAF
# 3      1    1  1/1/15           2859      N660MQ            SGF
# 4      1    1  1/1/15           5460      N583SW            RDD
#
#   DESTINATION_AIRPORT  CANCELLED CANCELLATION_REASON            ID
# 0                 SEA          1                   A   11136N431AS
# 1                 DFW          1                   B  112459N3BDAA
# 2                 IAH          1                   B  115254N746SK
# 3                 DFW          1                   B  112859N660MQ
# 4                 SFO          1                   A  115460N583SW

# %%
# Output File (CSV)
flight_data_2020_path = "Resources/2020_flights.csv"

# %%
flight_data_2020 = pd.read_csv(flight_data_2020_path)
flight_data_2020.head()
# Out:
#    MONTH  DAY     DATE  FLIGHT_NUMBER TAIL_NUMBER ORIGIN_AIRPORT  \
# 0      1    1   1/1/20           6173      N7831B            PDX
# 1      1    1   1/1/20           4433      N488WN            SNA
# 2      1   20  1/20/20            423      N209WN            DAL
# 3      1   20  1/20/20           1519      N467WN            DAL
# 4      1   30  1/30/20           1845      N741SA            MSY
#
#   DESTINATION_AIRPORT  CANCELLED CANCELLATION_CODE             ID
# 0                 LAS          1                 A   116173N7831B
# 1                 OAK          1                 A   114433N488WN
# 2                 PHX          1                 A   120423N209WN
# 3                 SAT          1                 A  1201519N467WN
# 4                 HOU          1                 A  1301845N741SA

# %%
flight_data_2015["ID"].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32494    False
# 32495    False
# 32496    False
# 32497    False
# 32498    False
# Name: ID, Length: 32499, dtype: bool

# %%
flight_data_2015 = flight_data_2015.loc[(flight_data_2015["MONTH"]==1)|(flight_data_2015["MONTH"]==2)]

# %%
flight_data_2015
# Out:
#        MONTH  DAY     Date  FLIGHT_NUMBER TAIL_NUMBER ORIGIN_AIRPORT  \
# 0          1    1   1/1/15            136      N431AS            ANC
# 1          1    1   1/1/15           2459      N3BDAA            PHX
# 2          1    1   1/1/15           5254      N746SK            MAF
# 3          1    1   1/1/15           2859      N660MQ            SGF
# 4          1    1   1/1/15           5460      N583SW            RDD
# ...      ...  ...      ...            ...         ...            ...
# 32494      2   28  2/28/15           1069      N3KBAA            DFW
# 32495      2   28  2/28/15           1329      N505AA            DFW
# 32496      2   28  2/28/15             81      N425AA            DFW
# 32497      2   28  2/28/15           2274      N4YAAA            DFW
# 32498      2   28  2/28/15           1230      N3JYAA            SEA
#
#       DESTINATION_AIRPORT  CANCELLED CANCELLATION_REASON             ID
# 0                     SEA          1                   A    11136N431AS
# 1                     DFW          1                   B   112459N3BDAA
# 2                     IAH          1                   B   115254N746SK
# 3                     DFW          1                   B   112859N660MQ
# 4                     SFO          1                   A   115460N583SW
# ...                   ...        ...                 ...            ...
# 32494                 DEN          1                   B  2281069N3KBAA
# 32495                 LAS          1                   B  2281329N505AA
# 32496                 TUS          1                   B    22881N425AA
# 32497                 OKC          1                   B  2282274N4YAAA
# 32498                 DFW          1                   B  2281230N3JYAA
#
# [32499 rows x 10 columns]

# %%
flight_data_2020["ID"].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12622    False
# 12623    False
# 12624    False
# 12625     True
# 12626    False
# Name: ID, Length: 12627, dtype: bool

# %%
flight_data_2020["ID"].drop_duplicates()
# Out:
# 0         116173N7831B
# 1         114433N488WN
# 2         120423N209WN
# 3        1201519N467WN
# 4        1301845N741SA
#              ...
# 12621           274358
# 12622     244359N112HQ
# 12623           254360
# 12624     274362N421YX
# 12626     274367N125HQ
# Name: ID, Length: 11283, dtype: object

# %%
flight_data_2020["ORIGIN_AIRPORT"].value_counts()
# Out:
# ORD    1405
# CLT     691
# DFW     524
# MDW     402
# DEN     346
#        ...
# BJI       1
# PVU       1
# STT       1
# ADK       1
# USA       1
# Name: ORIGIN_AIRPORT, Length: 326, dtype: int64

# %%
flight_data_2020 = flight_data_2020[flight_data_2020.ORIGIN_AIRPORT != "USA"]

# %%
flight_data_2020 = flight_data_2020[flight_data_2020.DESTINATION_AIRPORT != "USA"]

# %%
flight_data_2015["ORIGIN_AIRPORT"].value_counts()
# Out:
# ORD    2817
# DFW    2524
# LGA    1950
# BOS    1793
# EWR    1275
#        ...
# ITO       1
# BLI       1
# PBG       1
# BJI       1
# PIH       1
# Name: ORIGIN_AIRPORT, Length: 306, dtype: int64

# %%
count_2015_dest = flight_data_2015["DESTINATION_AIRPORT"].value_counts()

# %%
count_2015_dest_df = pd.DataFrame(count_2015_dest)
count_2015_dest_df.iloc[:10]
# Out:
#      DESTINATION_AIRPORT
# ORD                 2965
# DFW                 2647
# LGA                 1898
# BOS                 1781
# EWR                 1315
# ATL                 1291
# JFK                  957
# DCA                  851
# DEN                  703
# SFO                  677

# %%
count_2015_or = flight_data_2015["ORIGIN_AIRPORT"].value_counts()

# %%
count_2015_or_df = pd.DataFrame(count_2015_or)
count_2015_or_df.iloc[:10]
# Out:
#      ORIGIN_AIRPORT
# ORD            2817
# DFW            2524
# LGA            1950
# BOS            1793
# EWR            1275
# ATL            1195
# JFK             945
# DCA             890
# MDW             697
# DEN             674

# %%
#concat attempt, SQL join may be better

flights_all = pd.concat([flight_data_2015, flight_data_2020])

# %%
flights_all
# Out:
#        MONTH  DAY    Date  FLIGHT_NUMBER TAIL_NUMBER ORIGIN_AIRPORT  \
# 0          1    1  1/1/15            136      N431AS            ANC
# 1          1    1  1/1/15           2459      N3BDAA            PHX
# 2          1    1  1/1/15           5254      N746SK            MAF
# 3          1    1  1/1/15           2859      N660MQ            SGF
# 4          1    1  1/1/15           5460      N583SW            RDD
# ...      ...  ...     ...            ...         ...            ...
# 12622      2    4     NaN           4359      N112HQ            DCA
# 12623      2    5     NaN           4360         NaN            OKC
# 12624      2    7     NaN           4362      N421YX            LGA
# 12625      2    7     NaN           4362      N421YX            TYS
# 12626      2    7     NaN           4367      N125HQ            SDF
#
#       DESTINATION_AIRPORT  CANCELLED CANCELLATION_REASON            ID  \
# 0                     SEA          1                   A   11136N431AS
# 1                     DFW          1                   B  112459N3BDAA
# 2                     IAH          1                   B  115254N746SK
# 3                     DFW          1                   B  112859N660MQ
# 4                     SFO          1                   A  115460N583SW
# ...                   ...        ...                 ...           ...
# 12622                 OKC          1                 NaN  244359N112HQ
# 12623                 DCA          1                 NaN        254360
# 12624                 TYS          1                 NaN  274362N421YX
# 12625                 LGA          1                 NaN  274362N421YX
# 12626                 CLT          1                 NaN  274367N125HQ
#
#          DATE CANCELLATION_CODE
# 0         NaN               NaN
# 1         NaN               NaN
# 2         NaN               NaN
# 3         NaN               NaN
# 4         NaN               NaN
# ...       ...               ...
# 12622  2/4/20                 B
# 12623  2/5/20                 C
# 12624  2/7/20                 B
# 12625  2/7/20                 B
# 12626  2/7/20                 B
#
# [45124 rows x 12 columns]

# %%
flights_all = pd.merge(flight_data_2015, flight_data_2020, how="outer", on=["Date", "DATE"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-051c22d4b53d> in <module>
# ----> 1 flights_all = pd.merge(flight_data_2015, flight_data_2020, how="outer", on=["Date", "DATE"])
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
#      89     return op.get_result()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
#     651             self.join_names,
# --> 652         ) = self._get_merge_keys()
#     653
#     654         # validate the merge keys dtypes. We may need to coerce
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#    1003                     if not is_rkey(rk):
#    1004                         if rk is not None:
# -> 1005                             right_keys.append(right._get_label_or_level_values(rk))
#    1006                         else:
#    1007                             # work-around for merge_asof(right_index=True)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1558             values = self.axes[axis].get_level_values(key)._values
#    1559         else:
# -> 1560             raise KeyError(key)
#    1561
#    1562         # Check for duplicates
#
# KeyError: 'Date'
